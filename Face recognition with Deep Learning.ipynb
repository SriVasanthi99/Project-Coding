# %% [markdown]
# # Quick data visualization

# %%
# display some images for every different expression

import numpy as np
import seaborn as sns
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os

# size of the image: 48*48 pixels
pic_size = 48

# input path for the images
base_path = "C:/Users/user/Downloads/Automated_Attendance_System/images/"

plt.figure(0, figsize=(12,20))
cpt = 0

for expression in os.listdir(base_path + "train/"):
    for i in range(1,5):
        cpt = cpt + 1
        plt.subplot(7,4,cpt)
        img = load_img(base_path + "train/" + expression + "/" +os.listdir(base_path + "train/" + expression)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()

# %%
# count number of train images for each expression

for expression in os.listdir(base_path + "train"):
    print(str(len(os.listdir(base_path + "train/" + expression))) + " " + expression + " images")
# Out:
# 55 Jinping images
# 61 Martin images
# 61 modi images
# 61 Trumph images

# %% [markdown]
# # Setup the data generators

# %%
from keras.preprocessing.image import ImageDataGenerator

# number of images to feed into the NN for every batch
batch_size = 128

datagen_train = ImageDataGenerator()
datagen_validation = ImageDataGenerator()

train_generator = datagen_train.flow_from_directory(base_path + "train",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = datagen_validation.flow_from_directory(base_path + "validation",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 238 images belonging to 4 classes.
# Found 238 images belonging to 4 classes.

# %%
train_generator.class_indices
# Out:
# {'Jinping': 0, 'Martin': 1, 'Trumph': 2, 'modi': 3}

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam

# number of possible label values
nb_classes = 4

# Initialising the CNN
model = Sequential()

# 1 - Convolution
model.add(Conv2D(64,(3,3), padding='same', input_shape=(48, 48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 2nd Convolution layer
model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 3rd Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 4th Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(nb_classes, activation='softmax'))

opt = Adam(lr=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Train the model

# %%
# %%time

# number of epochs to train the NN
epochs = 50

from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("C:/Users/user/Downloads/Automated_Attendance_System/model_weights.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/50
# 1/1 [==============================] - 20s 20s/step - loss: 1.8261 - acc: 0.2273 - val_loss: 1.6503 - val_acc: 0.3750
#
# Epoch 00001: val_acc improved from -inf to 0.37500, saving model to C:/Users/user/Downloads/Automated_Attendance_System/model_weights.h5
# Epoch 2/50
# 1/1 [==============================] - 10s 10s/step - loss: 1.4742 - acc: 0.4297 - val_loss: 1.1339 - val_acc: 0.5455
#
# Epoch 00002: val_acc improved from 0.37500 to 0.54545, saving model to C:/Users/user/Downloads/Automated_Attendance_System/model_weights.h5
# Epoch 3/50
# 1/1 [==============================] - 9s 9s/step - loss: 1.1998 - acc: 0.4727 - val_loss: 1.1915 - val_acc: 0.4688
#
# Epoch 00003: val_acc did not improve from 0.54545
# Epoch 4/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.9966 - acc: 0.5781 - val_loss: 0.7633 - val_acc: 0.8182
#
# Epoch 00004: val_acc improved from 0.54545 to 0.81818, saving model to C:/Users/user/Downloads/Automated_Attendance_System/model_weights.h5
# Epoch 5/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.8544 - acc: 0.6909 - val_loss: 0.7948 - val_acc: 0.8438
#
# Epoch 00005: val_acc improved from 0.81818 to 0.84375, saving model to C:/Users/user/Downloads/Automated_Attendance_System/model_weights.h5
# Epoch 6/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.6221 - acc: 0.7656 - val_loss: 0.4888 - val_acc: 1.0000
#
# Epoch 00006: val_acc improved from 0.84375 to 1.00000, saving model to C:/Users/user/Downloads/Automated_Attendance_System/model_weights.h5
# Epoch 7/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.4663 - acc: 0.8672 - val_loss: 0.5009 - val_acc: 0.9766
#
# Epoch 00007: val_acc did not improve from 1.00000
# Epoch 8/50
# 1/1 [==============================] - 8s 8s/step - loss: 0.4090 - acc: 0.9091 - val_loss: 0.2992 - val_acc: 1.0000
#
# Epoch 00008: val_acc did not improve from 1.00000
# Epoch 9/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.2736 - acc: 0.9455 - val_loss: 0.3057 - val_acc: 1.0000
#
# Epoch 00009: val_acc did not improve from 1.00000
# Epoch 10/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.3546 - acc: 0.8984 - val_loss: 0.1756 - val_acc: 1.0000
#
# Epoch 00010: val_acc did not improve from 1.00000
# Epoch 11/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.2407 - acc: 0.9636 - val_loss: 0.1912 - val_acc: 1.0000
#
# Epoch 00011: val_acc did not improve from 1.00000
# Epoch 12/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.1755 - acc: 0.9844 - val_loss: 0.1086 - val_acc: 1.0000
#
# Epoch 00012: val_acc did not improve from 1.00000
# Epoch 13/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.1702 - acc: 0.9727 - val_loss: 0.1178 - val_acc: 1.0000
#
# Epoch 00013: val_acc did not improve from 1.00000
# Epoch 14/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.1329 - acc: 0.9844 - val_loss: 0.0708 - val_acc: 1.0000
#
# Epoch 00014: val_acc did not improve from 1.00000
# Epoch 15/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.1165 - acc: 0.9922 - val_loss: 0.0771 - val_acc: 1.0000
#
# Epoch 00015: val_acc did not improve from 1.00000
# Epoch 16/50
# 1/1 [==============================] - 8s 8s/step - loss: 0.0760 - acc: 1.0000 - val_loss: 0.0509 - val_acc: 1.0000
#
# Epoch 00016: val_acc did not improve from 1.00000
# Epoch 17/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0773 - acc: 1.0000 - val_loss: 0.0520 - val_acc: 1.0000
#
# Epoch 00017: val_acc did not improve from 1.00000
# Epoch 18/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0851 - acc: 1.0000 - val_loss: 0.0379 - val_acc: 1.0000
#
# Epoch 00018: val_acc did not improve from 1.00000
# Epoch 19/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0622 - acc: 1.0000 - val_loss: 0.0380 - val_acc: 1.0000
#
# Epoch 00019: val_acc did not improve from 1.00000
# Epoch 20/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0795 - acc: 0.9844 - val_loss: 0.0294 - val_acc: 1.0000
#
# Epoch 00020: val_acc did not improve from 1.00000
# Epoch 21/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0483 - acc: 1.0000 - val_loss: 0.0288 - val_acc: 1.0000
#
# Epoch 00021: val_acc did not improve from 1.00000
# Epoch 22/50
# 1/1 [==============================] - 8s 8s/step - loss: 0.0443 - acc: 1.0000 - val_loss: 0.0243 - val_acc: 1.0000
#
# Epoch 00022: val_acc did not improve from 1.00000
# Epoch 23/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0592 - acc: 1.0000 - val_loss: 0.0223 - val_acc: 1.0000
#
# Epoch 00023: val_acc did not improve from 1.00000
# Epoch 24/50
# 1/1 [==============================] - 8s 8s/step - loss: 0.0455 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 1.0000
#
# Epoch 00024: val_acc did not improve from 1.00000
# Epoch 25/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0425 - acc: 1.0000 - val_loss: 0.0176 - val_acc: 1.0000
#
# Epoch 00025: val_acc did not improve from 1.00000
# Epoch 26/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0532 - acc: 0.9922 - val_loss: 0.0197 - val_acc: 1.0000
#
# Epoch 00026: val_acc did not improve from 1.00000
# Epoch 27/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0251 - acc: 1.0000 - val_loss: 0.0146 - val_acc: 1.0000
#
# Epoch 00027: val_acc did not improve from 1.00000
# Epoch 28/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0288 - acc: 1.0000 - val_loss: 0.0193 - val_acc: 1.0000
#
# Epoch 00028: val_acc did not improve from 1.00000
# Epoch 29/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0300 - acc: 1.0000 - val_loss: 0.0123 - val_acc: 1.0000
#
# Epoch 00029: val_acc did not improve from 1.00000
# Epoch 30/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0235 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 1.0000
#
# Epoch 00030: val_acc did not improve from 1.00000
# Epoch 31/50
# 1/1 [==============================] - 8s 8s/step - loss: 0.0253 - acc: 1.0000 - val_loss: 0.0107 - val_acc: 1.0000
#
# Epoch 00031: val_acc did not improve from 1.00000
# Epoch 32/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0273 - acc: 1.0000 - val_loss: 0.0216 - val_acc: 1.0000
#
# Epoch 00032: val_acc did not improve from 1.00000
# Epoch 33/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0211 - acc: 1.0000 - val_loss: 0.0097 - val_acc: 1.0000
#
# Epoch 00033: val_acc did not improve from 1.00000
# Epoch 34/50
# 1/1 [==============================] - 8s 8s/step - loss: 0.0248 - acc: 1.0000 - val_loss: 0.0240 - val_acc: 1.0000
#
# Epoch 00034: val_acc did not improve from 1.00000
# Epoch 35/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0210 - acc: 1.0000 - val_loss: 0.0086 - val_acc: 1.0000
#
# Epoch 00035: val_acc did not improve from 1.00000
# Epoch 36/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0218 - acc: 1.0000 - val_loss: 0.0275 - val_acc: 1.0000
#
# Epoch 00036: val_acc did not improve from 1.00000
# Epoch 37/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0145 - acc: 1.0000 - val_loss: 0.0079 - val_acc: 1.0000
#
# Epoch 00037: val_acc did not improve from 1.00000
# Epoch 38/50
# 1/1 [==============================] - 8s 8s/step - loss: 0.0168 - acc: 1.0000 - val_loss: 0.0327 - val_acc: 1.0000
#
# Epoch 00038: val_acc did not improve from 1.00000
# Epoch 39/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0180 - acc: 1.0000 - val_loss: 0.0074 - val_acc: 1.0000
#
# Epoch 00039: val_acc did not improve from 1.00000
# Epoch 40/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0156 - acc: 1.0000 - val_loss: 0.0393 - val_acc: 1.0000
#
# Epoch 00040: val_acc did not improve from 1.00000
# Epoch 41/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0180 - acc: 1.0000 - val_loss: 0.0068 - val_acc: 1.0000
#
# Epoch 00041: val_acc did not improve from 1.00000
# Epoch 42/50
# 1/1 [==============================] - 8s 8s/step - loss: 0.0225 - acc: 1.0000 - val_loss: 0.0475 - val_acc: 1.0000
#
# Epoch 00042: val_acc did not improve from 1.00000
# Epoch 43/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0166 - acc: 1.0000 - val_loss: 0.0065 - val_acc: 1.0000
#
# Epoch 00043: val_acc did not improve from 1.00000
# Epoch 44/50
# 1/1 [==============================] - 8s 8s/step - loss: 0.0124 - acc: 1.0000 - val_loss: 0.0576 - val_acc: 1.0000
#
# Epoch 00044: val_acc did not improve from 1.00000
# Epoch 45/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0133 - acc: 1.0000 - val_loss: 0.0062 - val_acc: 1.0000
#
# Epoch 00045: val_acc did not improve from 1.00000
# Epoch 46/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0122 - acc: 1.0000 - val_loss: 0.0692 - val_acc: 1.0000
#
# Epoch 00046: val_acc did not improve from 1.00000
# Epoch 47/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0149 - acc: 1.0000 - val_loss: 0.0060 - val_acc: 1.0000
#
# Epoch 00047: val_acc did not improve from 1.00000
# Epoch 48/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0107 - acc: 1.0000 - val_loss: 0.0833 - val_acc: 1.0000
#
# Epoch 00048: val_acc did not improve from 1.00000
# Epoch 49/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.0100 - acc: 1.0000 - val_loss: 0.0058 - val_acc: 1.0000
#
# Epoch 00049: val_acc did not improve from 1.00000
# Epoch 50/50
# 1/1 [==============================] - 10s 10s/step - loss: 0.0106 - acc: 1.0000 - val_loss: 0.0992 - val_acc: 1.0000
#
# Epoch 00050: val_acc did not improve from 1.00000
# Wall time: 7min 52s

# %%
# serialize model structure to JSON
model_json = model.to_json()
with open("C:/Users/user/Downloads/Automated_Attendance_System/model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# # Analyze the results

# %%
# plot the evolution of Loss and Acuracy on the train and validation sets

import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['acc'], label='Training Accuracy')
plt.plot(history.history['val_acc'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
# show the confusion matrix of our predictions

# compute predictions
predictions = model.predict_generator(generator=validation_generator)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = validation_generator.classes
class_names = validation_generator.class_indices.keys()

from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()
